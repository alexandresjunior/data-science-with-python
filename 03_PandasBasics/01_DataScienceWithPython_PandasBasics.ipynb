# %% [markdown]
# # Data Science with Python - Pandas Basics
# ---

# %% [markdown]
# # PANDAS BASICS
# ---
#
# **version: 0.25.2**
#
# Pandas is a high-level data manipulation tool built on top of the Numpy package. The pandas package has very interesting data structures for data manipulation and is therefore widely used by data scientists.
#
#
# ## Data Structures
#
# ### Series
#
# Series are labeled one-dimensional arrays capable of storing any type of data. The row labels are called **index**. The basic way of creating a Series is as follows:
#
#
# ```
#     s = pd.Series(data, index = index)
# ```
#
# The *data* argument can be a dictionary, a list, a Numpy array or a constant.
#
# ### DataFrames
#
# DataFrame is a two-dimensional tabular data structure with row and column labels. Like Series, DataFrames are capable of storing any type of data.
#
#
# ```
#     df = pd.DataFrame(data, index = index, columns = columns)
# ```
#
# The *data* argument can be a dictionary, a list, a Numpy array, a Series and another DataFrame.
#
# **Documentation:** https://pandas.pydata.org/pandas-docs/version/0.25/

# %% [markdown]
# ## Data Structures

# %%
import pandas as pd

# %% [markdown]
# ### Creating a Series from a List

# %%
cars = ['Jetta Variant', 'Passat', 'Crossfox']
cars
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(cars)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Creating a DataFrame from a list of dictionaries

# %%
data = [
     {'Name': 'Jetta Variant', 'Engine': '4.0 Turbo Engine', 'Year': 2003, 'Mileage': 44410.0, 'Zero_km': False, 'Value': 88078.64},
     {'Name': 'Passat', 'Engine': 'Diesel Engine', 'Year': 1991, 'Mileage': 5712.0, 'Zero_km': False, 'Value': 106161.94},
     {'Name': 'Crossfox', 'Engine': 'V8 Diesel Engine', 'Year': 1990, 'Mileage': 37123.0, 'Zero_km': False, 'Value': 72832.16}
]

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#             Name            Engine  Year  Mileage  Zero_km      Value
# 0  Jetta Variant  4.0 Turbo Engine  2003  44410.0    False   88078.64
# 1         Passat     Diesel Engine  1991   5712.0    False  106161.94
# 2       Crossfox  V8 Diesel Engine  1990  37123.0    False   72832.16

# %%
dataset[['Name', 'Mileage', 'Zero_km', 'Value', 'Engine', 'Year']]    # Modify columns order
# Out:
#             Name  Mileage  Zero_km      Value            Engine  Year
# 0  Jetta Variant  44410.0    False   88078.64  4.0 Turbo Engine  2003
# 1         Passat   5712.0    False  106161.94     Diesel Engine  1991
# 2       Crossfox  37123.0    False   72832.16  V8 Diesel Engine  1990

# %% [markdown]
# ### Creating a DataFrame from a Dictionary (whose *values* are lists)

# %%
data = {
     'Name': ['Jetta Variant', 'Passat', 'Crossfox'],
     'Engine': ['4.0 Turbo Engine', 'Diesel Engine', 'V8 Diesel Engine'],
     'Year': [2003, 1991, 1990],
     'Mileage': [44410.0, 5712.0, 37123.0],
     'Zero_km': [False, False, False],
     'Value': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(data)

# %%
dataset
# Out:
#             Name            Engine  Year  Mileage  Zero_km      Value
# 0  Jetta Variant  4.0 Turbo Engine  2003  44410.0    False   88078.64
# 1         Passat     Diesel Engine  1991   5712.0    False  106161.94
# 2       Crossfox  V8 Diesel Engine  1990  37123.0    False   72832.16

# %% [markdown]
# ### Creating a DataFrame from an external file

# %%
dataset = pd.read_csv('db.csv', sep = ';', index_col = 0)

# %%
dataset
# Out:
#                                        Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant                4.0 Turbo Engine  2003  44410.0    False
# Passat                          Diesel Engine  1991   5712.0    False
# Crossfox                     V8 diesel engine  1990  37123.0    False
# DS5                           Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4             2.4 Turbo Engine  2006  25757.0    False
# ...                                       ...   ...      ...      ...
# Phantom 2013                        V8 engine  2014  27505.0    False
# Cadillac Ciel concept                Motor V8  1991  29981.0    False
# GLK class              5.0 V8 Bi-Turbo engine  2002  52637.0    False
# Aston Martin DB5                Diesel Engine  1996   7685.0    False
# Macan                        V6 diesel engine  1992  50188.0    False
#
#                                                              Accessories  \
# Name
# Jetta Variant          ['Alloy wheels', 'Power locks', 'Autopilot', '...
# Passat                 ['Multimedia Center', 'Panoramic Roof', 'ABS B...
# Crossfox               ['Autopilot', 'Stability control', 'Twilight s...
# DS5                    ['Power locks', '4 X 4', 'Power windows', 'Twi...
# Aston Martin DB4       ['Alloy wheels', '4 X 4', 'Multimedia center',...
# ...                                                                  ...
# Phantom 2013           ['Stability control', 'Autopilot', 'Automatic ...
# Cadillac Ciel concept  ['Leather seats', 'Digital panel', 'Rain senso...
# GLK class              ['Alloy wheels', 'Traction control', 'Automati...
# Aston Martin DB5       ['Air conditioning', '4 X 4', 'Automatic trans...
# Macan                  ['Multimedia center', 'Panoramic roof', 'Power...
#
#                            Value
# Name
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# GLK class               68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 6 columns]

# %% [markdown]
# ## Selections with DataFrames

# %%
dataset.head()    # 5 first rows
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant     4.0 Turbo Engine  2003  44410.0    False
# Passat               Diesel Engine  1991   5712.0    False
# Crossfox          V8 diesel engine  1990  37123.0    False
# DS5                Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4  2.4 Turbo Engine  2006  25757.0    False
#
#                                                         Accessories      Value
# Name
# Jetta Variant     ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# Passat            ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox          ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# DS5               ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07
# Aston Martin DB4  ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10

# %% [markdown]
# ### Selecting columns

# %%
dataset['Value']
# Out:
# Name
# Jetta Variant             88078.64
# Passat                   106161.94
# Crossfox                  72832.16
# DS5                      124549.07
# Aston Martin DB4          92612.10
#                            ...
# Phantom 2013              51759.58
# Cadillac Ciel concept     51667.06
# GLK class                 68934.03
# Aston Martin DB5         122110.90
# Macan                     90381.47
# Name: Value, Length: 258, dtype: float64

# %%
type(dataset['Value'])
# Out:
# pandas.core.series.Series

# %%
dataset[['Value']]
# Out:
#                            Value
# Name
# Jetta Variant           88078.64
# Passat                 106161.94
# Crossfox                72832.16
# DS5                    124549.07
# Aston Martin DB4        92612.10
# ...                          ...
# Phantom 2013            51759.58
# Cadillac Ciel concept   51667.06
# GLK class               68934.03
# Aston Martin DB5       122110.90
# Macan                   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[['Value']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecting lines - [ i : j ]
#
# **Note:** Indexing originates from zero and in *slices* the row with index *i* is **included** and the row with index *j* is **not is included** in the result.

# %%
dataset[0:3]
# Out:
#                          Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant  4.0 Turbo Engine  2003  44410.0    False
# Passat            Diesel Engine  1991   5712.0    False
# Crossfox       V8 diesel engine  1990  37123.0    False
#
#                                                      Accessories      Value
# Name
# Jetta Variant  ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# Passat         ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox       ['Autopilot', 'Stability control', 'Twilight s...   72832.16

# %% [markdown]
# ### Using *.loc* for selections
#
# **Note:** Selects a group of rows and columns according to labels or a boolean matrix.

# %%
dataset.loc['Passat']
# Out:
# Engine                                             Diesel Engine
# Year                                                        1991
# Mileage                                                   5712.0
# Zero_km                                                    False
# Accessories    ['Multimedia Center', 'Panoramic Roof', 'ABS B...
# Value                                                  106161.94
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'DS5']]
# Out:
#                  Engine  Year  Mileage  Zero_km  \
# Name
# Passat    Diesel Engine  1991   5712.0    False
# DS5     Motor 2.4 Turbo  2019      NaN     True
#
#                                               Accessories      Value
# Name
# Passat  ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# DS5     ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07

# %%
dataset.loc[['Passat', 'DS5'], ['Engine', 'Value']]
# Out:
#                  Engine      Value
# Name
# Passat    Diesel Engine  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
dataset.loc[:, ['Engine', 'Value']]
# Out:
#                                        Engine      Value
# Name
# Jetta Variant                4.0 Turbo Engine   88078.64
# Passat                          Diesel Engine  106161.94
# Crossfox                     V8 diesel engine   72832.16
# DS5                           Motor 2.4 Turbo  124549.07
# Aston Martin DB4             2.4 Turbo Engine   92612.10
# ...                                       ...        ...
# Phantom 2013                        V8 engine   51759.58
# Cadillac Ciel concept                Motor V8   51667.06
# GLK class              5.0 V8 Bi-Turbo engine   68934.03
# Aston Martin DB5                Diesel Engine  122110.90
# Macan                        V6 diesel engine   90381.47
#
# [258 rows x 2 columns]

# %% [markdown]
# ### Using *.iloc* for selections
#
# **Note:** Selects based on indices, i.e. based on the position of the information.

# %%
dataset.head()
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant     4.0 Turbo Engine  2003  44410.0    False
# Passat               Diesel Engine  1991   5712.0    False
# Crossfox          V8 diesel engine  1990  37123.0    False
# DS5                Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4  2.4 Turbo Engine  2006  25757.0    False
#
#                                                         Accessories      Value
# Name
# Jetta Variant     ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# Passat            ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox          ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# DS5               ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07
# Aston Martin DB4  ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10

# %%
dataset.iloc[[1]]
# Out:
#                Engine  Year  Mileage  Zero_km  \
# Name
# Passat  Diesel Engine  1991   5712.0    False
#
#                                               Accessories      Value
# Name
# Passat  ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94

# %%
dataset.iloc[1:4]
# Out:
#                     Engine  Year  Mileage  Zero_km  \
# Name
# Passat       Diesel Engine  1991   5712.0    False
# Crossfox  V8 diesel engine  1990  37123.0    False
# DS5        Motor 2.4 Turbo  2019      NaN     True
#
#                                                 Accessories      Value
# Name
# Passat    ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox  ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# DS5       ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07

# %%
dataset.iloc[1:4, [0, 5, 2]]
# Out:
#                     Engine      Value  Mileage
# Name
# Passat       Diesel Engine  106161.94   5712.0
# Crossfox  V8 diesel engine   72832.16  37123.0
# DS5        Motor 2.4 Turbo  124549.07      NaN

# %%
dataset.iloc[[1, 42, 22], [0, 5, 2]]
# Out:
#                                Engine      Value  Mileage
# Name
# Passat                  Diesel Engine  106161.94   5712.0
# Optima                  Motor 1.8 16v   86641.34      NaN
# Lamborghini Obvious  V6 Diesel Engine  133529.84  98079.0

# %%
dataset.iloc[:, [0, 5, 2]]
# Out:
#                                        Engine      Value  Mileage
# Name
# Jetta Variant                4.0 Turbo Engine   88078.64  44410.0
# Passat                          Diesel Engine  106161.94   5712.0
# Crossfox                     V8 diesel engine   72832.16  37123.0
# DS5                           Motor 2.4 Turbo  124549.07      NaN
# Aston Martin DB4             2.4 Turbo Engine   92612.10  25757.0
# ...                                       ...        ...      ...
# Phantom 2013                        V8 engine   51759.58  27505.0
# Cadillac Ciel concept                Motor V8   51667.06  29981.0
# GLK class              5.0 V8 Bi-Turbo engine   68934.03  52637.0
# Aston Martin DB5                Diesel Engine  122110.90   7685.0
# Macan                        V6 diesel engine   90381.47  50188.0
#
# [258 rows x 3 columns]

# %% [markdown]
# ## Queries with DataFrames

# %%
dataset.head()
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant     4.0 Turbo Engine  2003  44410.0    False
# Passat               Diesel Engine  1991   5712.0    False
# Crossfox          V8 diesel engine  1990  37123.0    False
# DS5                Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4  2.4 Turbo Engine  2006  25757.0    False
#
#                                                         Accessories      Value
# Name
# Jetta Variant     ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# Passat            ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox          ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# DS5               ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07
# Aston Martin DB4  ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10

# %%
dataset.Engine
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
select = dataset.Engine == 'Diesel Engine'

# %%
type(select)        # boolean series: dataset.Engine == 'Diesel Engine'
# Out:
# pandas.core.series.Series

# %%
dataset[select]
# Out:
#                                 Engine  Year   Mileage  Zero_km  \
# Name
# Passat                   Diesel Engine  1991    5712.0    False
# Effa Hafei Pickup Trunk  Diesel Engine  1991  102959.0    False
# Sorento                  Diesel Engine  2019       NaN     True
# New Fiesta Hatch         Diesel Engine  2017  118895.0    False
# Kangoo Express           Diesel Engine  2007   29132.0    False
# Fit                      Diesel Engine  2013   44329.0    False
# Symbol                   Diesel Engine  2016  117714.0    False
# A4 Sedan                 Diesel Engine  2002   30511.0    False
# A4 Avant                 Diesel Engine  2014   17357.0    False
# Silver Shadow            Diesel Engine  2015   99052.0    False
# Camry                    Diesel Engine  2019       NaN     True
# Clio                     Diesel Engine  1990   66437.0    False
# Series 3 M3 Coupé        Diesel Engine  2013   19896.0    False
# Chana Utility            Diesel Engine  2009   52034.0    False
# TT Roadster              Diesel Engine  1998  107392.0    False
# Aston Martin Virage      Diesel Engine  2019       NaN     True
# Sandero                  Diesel Engine  2015   34783.0    False
# XKR                      Diesel Engine  1996   85127.0    False
# X5                       Diesel Engine  2002   13606.0    False
# Dodge Dakota             Diesel Engine  1993   71544.0    False
# i30 CW                   Diesel Engine  2015    8497.0    False
# 7 Series Sedan           Diesel Engine  2019       NaN     True
# Aston Martin DB5         Diesel Engine  1996    7685.0    False
#
#                                                                Accessories  \
# Name
# Passat                   ['Multimedia Center', 'Panoramic Roof', 'ABS B...
# Effa Hafei Pickup Trunk  ['Stability control', 'Digital panel', 'Electr...
# Sorento                  ['Rain sensor', 'Parking camera', 'Parking sen...
# New Fiesta Hatch         ['Parking sensor', 'Power locks', 'Autopilot',...
# Kangoo Express           ['Leather seats', 'Automatic gearshift', 'Auto...
# Fit                      ['ABS Brakes', 'Parking Camera', 'Automatic Tr...
# Symbol                   ['4 X 4', 'Autopilot', 'Twilight sensor', 'Par...
# A4 Sedan                 ['Parking camera', '4 X 4', 'Power locks', 'Ai...
# A4 Avant                 ['Panoramic roof', '4 X 4', 'Leather seats', '...
# Silver Shadow            ['4 X 4', 'Multimedia Center', 'Air conditioni...
# Camry                    ['Power locks', 'Alloy wheels', 'Twilight sens...
# Clio                     ['4 X 4', 'Automatic transmission', 'ABS brake...
# Series 3 M3 Coupé        ['Leather seats', 'Rain sensor', 'Air conditio...
# Chana Utility            ['Air conditioning', 'Parking sensor', 'Autopi...
# TT Roadster              ['Air conditioning', 'Parking sensor', 'Tracti...
# Aston Martin Virage      ['Power Locks', 'Traction Control', 'Parking C...
# Sandero                  ['Autopilot', 'Panoramic roof', 'Automatic tra...
# XKR                      ['Traction control', 'Air conditioning', 'Powe...
# X5                       ['Traction control', 'Autopilot', 'Power locks...
# Dodge Dakota             ['Traction Control', 'Parking Sensor', 'Autopi...
# i30 CW                   ['Rain sensor', 'Power windows', 'Stability co...
# 7 Series Sedan           ['Power windows', 'Power locks', 'Alloy wheels...
# Aston Martin DB5         ['Air conditioning', '4 X 4', 'Automatic trans...
#
#                              Value
# Name
# Passat                   106161.94
# Effa Hafei Pickup Trunk  125684.65
# Sorento                   81399.35
# New Fiesta Hatch          66007.16
# Kangoo Express           146716.91
# Fit                       77836.23
# Symbol                   133030.60
# A4 Sedan                  96369.04
# A4 Avant                 138946.88
# Silver Shadow            143568.22
# Camry                    138597.27
# Clio                     111130.33
# Series 3 M3 Coupé         69219.89
# Chana Utility            132662.32
# TT Roadster               85311.40
# Aston Martin Virage       97290.18
# Sandero                  112350.61
# XKR                       54263.16
# X5                        62041.32
# Dodge Dakota             141083.35
# i30 CW                    73311.75
# 7 Series Sedan            67539.79
# Aston Martin DB5         122110.90

# %%
dataset[(dataset.Engine == 'Diesel Engine') & (dataset.Zero_km == True)]
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Sorento              Diesel Engine  2019      NaN     True
# Camry                Diesel Engine  2019      NaN     True
# Aston Martin Virage  Diesel Engine  2019      NaN     True
# 7 Series Sedan       Diesel Engine  2019      NaN     True
#
#                                                            Accessories  \
# Name
# Sorento              ['Rain sensor', 'Parking camera', 'Parking sen...
# Camry                ['Power locks', 'Alloy wheels', 'Twilight sens...
# Aston Martin Virage  ['Power Locks', 'Traction Control', 'Parking C...
# 7 Series Sedan       ['Power windows', 'Power locks', 'Alloy wheels...
#
#                          Value
# Name
# Sorento               81399.35
# Camry                138597.27
# Aston Martin Virage   97290.18
# 7 Series Sedan        67539.79

# %%
(dataset.Engine == 'Diesel Engine') & (dataset.Zero_km == True)       # boolean series  (& / |)
# Out:
# Name
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# GLK class                False
# Aston Martin DB5         False
# Macan                    False
# Length: 258, dtype: bool

# %% [markdown]
# ### Using the query method

# %%
dataset.query('Engine == "Diesel Engine" and Zero_km == True')      # boolean series  (& / |) / (and / or)
# Out:
#                             Motor  ...      Valor
# Nome                               ...
# Sorento              Motor Diesel  ...   81399.35
# Cielo Hatch          Motor Diesel  ...  145197.70
# Camry                Motor Diesel  ...  138597.27
# Aston Martin Virage  Motor Diesel  ...   97290.18
# Série 7 Sedã         Motor Diesel  ...   67539.79
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Iterating with DataFrames

# %%
dataset.head()
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant     4.0 Turbo Engine  2003  44410.0    False
# Passat               Diesel Engine  1991   5712.0    False
# Crossfox          V8 diesel engine  1990  37123.0    False
# DS5                Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4  2.4 Turbo Engine  2006  25757.0    False
#
#                                                         Accessories      Value
# Name
# Jetta Variant     ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# Passat            ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# Crossfox          ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# DS5               ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07
# Aston Martin DB4  ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10

# %%
for item in dataset:
  print(item)
# Out:
# Engine
# Year
# Mileage
# Zero_km
# Accessories
# Value

# %%
for index, row in dataset.iterrows():
  if (2019 - row['Year'] != 0):
    dataset.loc[index, 'Km_avg'] = row['Mileage'] / (2019 - row['Year'])
  else:
    dataset.loc[index, 'Km_avg'] = 0
    
dataset
# Out:
#                                        Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant                4.0 Turbo Engine  2003  44410.0    False
# Passat                          Diesel Engine  1991   5712.0    False
# Crossfox                     V8 diesel engine  1990  37123.0    False
# DS5                           Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4             2.4 Turbo Engine  2006  25757.0    False
# ...                                       ...   ...      ...      ...
# Phantom 2013                        V8 engine  2014  27505.0    False
# Cadillac Ciel concept                Motor V8  1991  29981.0    False
# GLK class              5.0 V8 Bi-Turbo engine  2002  52637.0    False
# Aston Martin DB5                Diesel Engine  1996   7685.0    False
# Macan                        V6 diesel engine  1992  50188.0    False
#
#                                                              Accessories  \
# Name
# Jetta Variant          ['Alloy wheels', 'Power locks', 'Autopilot', '...
# Passat                 ['Multimedia Center', 'Panoramic Roof', 'ABS B...
# Crossfox               ['Autopilot', 'Stability control', 'Twilight s...
# DS5                    ['Power locks', '4 X 4', 'Power windows', 'Twi...
# Aston Martin DB4       ['Alloy wheels', '4 X 4', 'Multimedia center',...
# ...                                                                  ...
# Phantom 2013           ['Stability control', 'Autopilot', 'Automatic ...
# Cadillac Ciel concept  ['Leather seats', 'Digital panel', 'Rain senso...
# GLK class              ['Alloy wheels', 'Traction control', 'Automati...
# Aston Martin DB5       ['Air conditioning', '4 X 4', 'Automatic trans...
# Macan                  ['Multimedia center', 'Panoramic roof', 'Power...
#
#                            Value       Km_avg
# Name
# Jetta Variant           88078.64  2775.625000
# Passat                 106161.94   204.000000
# Crossfox                72832.16  1280.103448
# DS5                    124549.07     0.000000
# Aston Martin DB4        92612.10  1981.307692
# ...                          ...          ...
# Phantom 2013            51759.58  5501.000000
# Cadillac Ciel concept   51667.06  1070.750000
# GLK class               68934.03  3096.294118
# Aston Martin DB5       122110.90   334.130435
# Macan                   90381.47  1858.814815
#
# [258 rows x 7 columns]

# %% [markdown]
# ## Data processing

# %%
dataset.head()
# Out:
#                             Engine  Year  Mileage  Zero_km  \
# Name
# Jetta Variant     4.0 Turbo Engine  2003  44410.0    False
# Passat               Diesel Engine  1991   5712.0    False
# Crossfox          V8 diesel engine  1990  37123.0    False
# DS5                Motor 2.4 Turbo  2019      NaN     True
# Aston Martin DB4  2.4 Turbo Engine  2006  25757.0    False
#
#                                                         Accessories  \
# Name
# Jetta Variant     ['Alloy wheels', 'Power locks', 'Autopilot', '...
# Passat            ['Multimedia Center', 'Panoramic Roof', 'ABS B...
# Crossfox          ['Autopilot', 'Stability control', 'Twilight s...
# DS5               ['Power locks', '4 X 4', 'Power windows', 'Twi...
# Aston Martin DB4  ['Alloy wheels', '4 X 4', 'Multimedia center',...
#
#                       Value       Km_avg
# Name
# Jetta Variant      88078.64  2775.625000
# Passat            106161.94   204.000000
# Crossfox           72832.16  1280.103448
# DS5               124549.07     0.000000
# Aston Martin DB4   92612.10  1981.307692

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Engine       258 non-null    object
#  1   Year         258 non-null    int64
#  2   Mileage      197 non-null    float64
#  3   Zero_km      258 non-null    bool
#  4   Accessories  258 non-null    object
#  5   Value        258 non-null    float64
#  6   Km_avg       258 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 22.5+ KB

# %%
dataset.Mileage.isna()
# Out:
# Name
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# GLK class                False
# Aston Martin DB5         False
# Macan                    False
# Name: Mileage, Length: 258, dtype: bool

# %%
dataset[dataset.Mileage.isna()]
# Out:
#                                 Engine  Year  Mileage  Zero_km  \
# Name
# DS5                    Motor 2.4 Turbo  2019      NaN     True
# A5                    4.0 Turbo Engine  2019      NaN     True
# J5                           V6 engine  2019      NaN     True
# A3                        Motor 1.0 8v  2019      NaN     True
# Series 1 M                   V8 engine  2019      NaN     True
# ...                                ...   ...      ...      ...
# Lamborghini Reventón   Motor 4.0 Turbo  2019      NaN     True
# Benni Mini                   V8 engine  2019      NaN     True
# Uno                    Motor Diesel V6  2019      NaN     True
# Santa Fe                 Motor 3.0 32v  2019      NaN     True
# XC60                  4.0 Turbo Engine  2019      NaN     True
#
#                                                             Accessories  \
# Name
# DS5                   ['Power locks', '4 X 4', 'Power windows', 'Twi...
# A5                    ['Automatic transmission', 'Parking camera', '...
# J5                    ['Twilight sensor', 'Digital panel', 'Alloy wh...
# A3                    ['4 X 4', 'Autopilot', 'Multimedia Center', 'P...
# Series 1 M            ['Stability control', 'Multimedia center', 'Di...
# ...                                                                 ...
# Lamborghini Reventón  ['Traction control', 'Air conditioning', 'Mult...
# Benni Mini            ['Twilight sensor', 'Automatic transmission', ...
# Uno                   ['Multimedia center', 'Twilight sensor', 'Stab...
# Santa Fe              ['Electric locks', 'Air conditioning', '4 X 4'...
# XC60                  ['Digital Dashboard', 'Autopilot', 'Multimedia...
#
#                           Value  Km_avg
# Name
# DS5                   124549.07     0.0
# A5                     56445.20     0.0
# J5                     53183.38     0.0
# A3                     88552.39     0.0
# Series 1 M             94564.40     0.0
# ...                         ...     ...
# Lamborghini Reventón   67664.86     0.0
# Benni Mini            126247.84     0.0
# Uno                   128852.21     0.0
# Santa Fe              129415.33     0.0
# XC60                   77675.79     0.0
#
# [61 rows x 7 columns]

# %%
dataset.fillna(0, inplace = True)     # Without 'inplace' property, it would only change visualization

# %%
dataset.query("Zero_km == True")
# Out:
#                                 Engine  Year  Mileage  Zero_km  \
# Name
# DS5                    Motor 2.4 Turbo  2019      0.0     True
# A5                    4.0 Turbo Engine  2019      0.0     True
# J5                           V6 engine  2019      0.0     True
# A3                        Motor 1.0 8v  2019      0.0     True
# Series 1 M                   V8 engine  2019      0.0     True
# ...                                ...   ...      ...      ...
# Lamborghini Reventón   Motor 4.0 Turbo  2019      0.0     True
# Benni Mini                   V8 engine  2019      0.0     True
# Uno                    Motor Diesel V6  2019      0.0     True
# Santa Fe                 Motor 3.0 32v  2019      0.0     True
# XC60                  4.0 Turbo Engine  2019      0.0     True
#
#                                                             Accessories  \
# Name
# DS5                   ['Power locks', '4 X 4', 'Power windows', 'Twi...
# A5                    ['Automatic transmission', 'Parking camera', '...
# J5                    ['Twilight sensor', 'Digital panel', 'Alloy wh...
# A3                    ['4 X 4', 'Autopilot', 'Multimedia Center', 'P...
# Series 1 M            ['Stability control', 'Multimedia center', 'Di...
# ...                                                                 ...
# Lamborghini Reventón  ['Traction control', 'Air conditioning', 'Mult...
# Benni Mini            ['Twilight sensor', 'Automatic transmission', ...
# Uno                   ['Multimedia center', 'Twilight sensor', 'Stab...
# Santa Fe              ['Electric locks', 'Air conditioning', '4 X 4'...
# XC60                  ['Digital Dashboard', 'Autopilot', 'Multimedia...
#
#                           Value  Km_avg
# Name
# DS5                   124549.07     0.0
# A5                     56445.20     0.0
# J5                     53183.38     0.0
# A3                     88552.39     0.0
# Series 1 M             94564.40     0.0
# ...                         ...     ...
# Lamborghini Reventón   67664.86     0.0
# Benni Mini            126247.84     0.0
# Uno                   128852.21     0.0
# Santa Fe              129415.33     0.0
# XC60                   77675.79     0.0
#
# [61 rows x 7 columns]

# %%
dataset = pd.read_csv('db.csv', sep = ';')

# %%
dataset
# Out:
#                       Name                  Engine  Year  Mileage  Zero_km  \
# 0            Jetta Variant        4.0 Turbo Engine  2003  44410.0    False
# 1                   Passat           Diesel Engine  1991   5712.0    False
# 2                 Crossfox        V8 diesel engine  1990  37123.0    False
# 3                      DS5         Motor 2.4 Turbo  2019      NaN     True
# 4         Aston Martin DB4        2.4 Turbo Engine  2006  25757.0    False
# ..                     ...                     ...   ...      ...      ...
# 253           Phantom 2013               V8 engine  2014  27505.0    False
# 254  Cadillac Ciel concept                Motor V8  1991  29981.0    False
# 255              GLK class  5.0 V8 Bi-Turbo engine  2002  52637.0    False
# 256       Aston Martin DB5           Diesel Engine  1996   7685.0    False
# 257                  Macan        V6 diesel engine  1992  50188.0    False
#
#                                            Accessories      Value
# 0    ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# 1    ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# 2    ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# 3    ['Power locks', '4 X 4', 'Power windows', 'Twi...  124549.07
# 4    ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10
# ..                                                 ...        ...
# 253  ['Stability control', 'Autopilot', 'Automatic ...   51759.58
# 254  ['Leather seats', 'Digital panel', 'Rain senso...   51667.06
# 255  ['Alloy wheels', 'Traction control', 'Automati...   68934.03
# 256  ['Air conditioning', '4 X 4', 'Automatic trans...  122110.90
# 257  ['Multimedia center', 'Panoramic roof', 'Power...   90381.47
#
# [258 rows x 7 columns]

# %%
dataset.dropna(subset = ['Mileage'], inplace = True)

# %%
dataset
# Out:
#                       Name                  Engine  Year  Mileage  Zero_km  \
# 0            Jetta Variant        4.0 Turbo Engine  2003  44410.0    False
# 1                   Passat           Diesel Engine  1991   5712.0    False
# 2                 Crossfox        V8 diesel engine  1990  37123.0    False
# 4         Aston Martin DB4        2.4 Turbo Engine  2006  25757.0    False
# 5            Palio Weekend           Motor 1.8 16v  2012  10728.0    False
# ..                     ...                     ...   ...      ...      ...
# 253           Phantom 2013               V8 engine  2014  27505.0    False
# 254  Cadillac Ciel concept                Motor V8  1991  29981.0    False
# 255              GLK class  5.0 V8 Bi-Turbo engine  2002  52637.0    False
# 256       Aston Martin DB5           Diesel Engine  1996   7685.0    False
# 257                  Macan        V6 diesel engine  1992  50188.0    False
#
#                                            Accessories      Value
# 0    ['Alloy wheels', 'Power locks', 'Autopilot', '...   88078.64
# 1    ['Multimedia Center', 'Panoramic Roof', 'ABS B...  106161.94
# 2    ['Autopilot', 'Stability control', 'Twilight s...   72832.16
# 4    ['Alloy wheels', '4 X 4', 'Multimedia center',...   92612.10
# 5    ['Parking sensor', 'Panoramic roof', 'Twilight...   97497.73
# ..                                                 ...        ...
# 253  ['Stability control', 'Autopilot', 'Automatic ...   51759.58
# 254  ['Leather seats', 'Digital panel', 'Rain senso...   51667.06
# 255  ['Alloy wheels', 'Traction control', 'Automati...   68934.03
# 256  ['Air conditioning', '4 X 4', 'Automatic trans...  122110.90
# 257  ['Multimedia center', 'Panoramic roof', 'Power...   90381.47
#
# [197 rows x 7 columns]
